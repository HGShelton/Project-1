# %%
#importing libraries
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.geometry import Point, Polygon
# import hvplot.pandas
import scipy.stats as stats
import random

# %%
#reading in the csv file
staten_island_df = pd.read_csv("Resources/staten_island.csv").set_index("OBJECTID")
queens_df = pd.read_csv("Resources/queens.csv").set_index("OBJECTID")
bronx_df = pd.read_csv("Resources/bronx.csv").set_index("OBJECTID")
manhattan_df = pd.read_csv("Resources/manhattan.csv").set_index("OBJECTID")
staten_island_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 390 entries, 1 to 390
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Complaint ID  366 non-null    object
#  1   Offense       366 non-null    object
#  2   Latitude      390 non-null    float64
#  3   Longitude     390 non-null    float64
#  4   Borough       24 non-null     object
#  5   Public Area   24 non-null     object
# dtypes: float64(2), object(4)
# memory usage: 21.3+ KB

# %%
#the brooklyn dataframe is different for whatever reason
k_crimes = pd.read_csv("Resources/nyc_crimes_total.csv").set_index("OBJECTID")
k_crimes = k_crimes[k_crimes["BORO_NM"] == "BROOKLYN"]
k_public = pd.read_csv("Resources/nyc_public_total.csv").set_index("OBJECTID")
k_public = k_public[k_public["boro"] == "BROOKLYN"]

# %%
k_crimes.head()
# Out:
#           Offense   BORO_NM   Latitude  Longitude
# OBJECTID
# 180          RAPE  BROOKLYN  40.658158 -74.000441
# 261       ROBBERY  BROOKLYN  40.605049 -73.990582
# 287       ROBBERY  BROOKLYN  40.575023 -73.989880
# 316       ROBBERY  BROOKLYN  40.589863 -73.983958
# 455       ROBBERY  BROOKLYN  40.629252 -73.965003

# %%
k_crimes_gdf.head()
# Out:
#           Offense   BORO_NM   Latitude  Longitude  \
# OBJECTID
# 180          RAPE  BROOKLYN  40.658158 -74.000441
# 261       ROBBERY  BROOKLYN  40.605049 -73.990582
# 287       ROBBERY  BROOKLYN  40.575023 -73.989880
# 316       ROBBERY  BROOKLYN  40.589863 -73.983958
# 455       ROBBERY  BROOKLYN  40.629252 -73.965003
#
#                                    geometry
# OBJECTID
# 180       POINT (4526045.417 -12515723.379)
# 261       POINT (4520133.378 -12511742.729)
# 287       POINT (4516790.899 -12511459.386)
# 316       POINT (4518442.881 -12509069.617)
# 455       POINT (4522827.644 -12501426.281)

# %% [markdown]
# **Cleaning Data**
#
# - the data frame is stacked on top of each other by the longitude and latitude columns
# - we are simply breaking up the data into crimes and public institutions

# %%
def dividedf(df1):
    x = df1.drop(columns=["facname", "Public Area", "Public Area (supergroup)"])
    x = x.dropna()
    y = df1[["facname", "Public Area", "Public Area (supergroup)", "Latitude", "Longitude"]]
    y = y.dropna().reset_index()
    return x, y

# %%
#dividing the df into crimes and public institutions
# r_crimes = staten_island_df.iloc[0:365, :]
r_crimes = staten_island_df.drop(columns= ["Borough", "Public Area"])
r_crimes = r_crimes.dropna()

# %%
#same method for public institutions and reordering columns
# r_public = staten_island_df.iloc[366:389, :]
r_public = staten_island_df[["Public Area", "Latitude", "Longitude"]]
r_public = r_public.dropna().reset_index()

# %%
r_public.head()
# Out:
#    OBJECTID                      Public Area   Latitude  Longitude
# 0       367                            PARKS  40.614533 -74.074185
# 1       368  RECREATION AND WATERFRONT SITES  40.510392 -74.230405
# 2       369                 PUBLIC LIBRARIES  40.595802 -74.063027
# 3       370                 PUBLIC LIBRARIES  40.590395 -74.101138
# 4       371                            PARKS  40.638748 -74.083899

# %%
df= dividedf(queens_df)
q_crimes = df[0]
q_public = df[1]

# %%
df= dividedf(bronx_df)
x_crimes = df[0]
x_public = df[1]

# %%
x_public.head()
# Out:
#    OBJECTID               facname                      Public Area  \
# 0      5348       ST. LUKE'S PARK                          GARDENS
# 1      5349     SOUNDVIEW LIBRARY                 PUBLIC LIBRARIES
# 2      5350  HORSESHOE PLAYGROUND  RECREATION AND WATERFRONT SITES
# 3      5351    BAYCHESTER LIBRARY                 PUBLIC LIBRARIES
# 4      5352    ESTELLA DIGGS PARK                            PARKS
#
#   Public Area (supergroup)   Latitude  Longitude
# 0         PARKS AND PLAZAS  40.805637 -73.915384
# 1                LIBRARIES  40.818708 -73.862889
# 2         PARKS AND PLAZAS  40.824121 -73.897692
# 3                LIBRARIES  40.870278 -73.828611
# 4         PARKS AND PLAZAS  40.828938 -73.906177

# %%
df= dividedf(manhattan_df)
m_crimes = df[0]
m_public = df[1]

# %% [markdown]
# **Finding the Crimes that Occured Near Public Institutions**
#
# - using GeoPandasDataFrame, we are marking the coordinates of each public institution
# - then, we are finding the number of crimes that occured within a 1 mile radius of that institution
# - we are looking at the results by type of crime which we have narrowed down to robbery, murder/manslaughter, and rape

# %%
def creategdf (crimes, public):
#each crime
    x = gpd.GeoDataFrame(
        crimes,
        geometry=gpd.points_from_xy(
            crimes["Latitude"],
            crimes["Longitude"],
        ),
        crs="EPSG:4326",
    )

# each public institution
    y = gpd.GeoDataFrame(
        public,
        geometry=gpd.points_from_xy(
            public["Latitude"],
            public["Longitude"],
        ),
        crs="EPSG:4326",
    )

    # EPSG:3857 converts geometry points to meters
    x = x.to_crs(3857)
    y = y.to_crs(3857)
    return x, y

# %%
df = creategdf(r_crimes, r_public)
r_crimes_gdf = df[0]
r_public_gdf = df[1]

# %%
df = creategdf(q_crimes, q_public)
q_crimes_gdf = df[0]
q_public_gdf = df[1]

# %%
df = creategdf(k_crimes, k_public)
k_crimes_gdf = df[0]
k_public_gdf = df[1]

# %%
df = creategdf(x_crimes, x_public)
x_crimes_gdf = df[0]
x_public_gdf = df[1]

# %%
df = creategdf(m_crimes, m_public)
m_crimes_gdf = df[0]
m_public_gdf = df[1]

# %%
#repeating method to get number of crimes within a mile radius of each random point
#create empty list to hold the number of crimes commited within a 1 mile radius of each location
crimes_per_location = []

#NOTE: radius is in meters
def crimesper (crimes_gdf, public_gdf, radius):
    radius = radius
    for offense in crimes_gdf["Offense"]:
        crimes_per_location = []
        crimes_gdf_each = crimes_gdf[crimes_gdf["Offense"] == offense]

        for i in range(len(public_gdf)):

            # Calculate the distances between all pairs of points
            distances = gpd.GeoSeries(crimes_gdf_each.geometry).distance(public_gdf.geometry.iloc[i])

            # Filter the pairs where the distance is within the radius
            within_radius = distances <= radius

            # Count the number of points within the radius for each point in gdf2
            count_within_radius = within_radius.sum()
            
            crimes_per_location.append(count_within_radius)
        public_gdf[offense] = crimes_per_location

    #creating a column for the sum amount of offenses
    public_gdf["Total Crimes"] = public_gdf[['ROBBERY', 'MURDER & NON-NEGL. MANSLAUGHTER', 'RAPE']].sum(axis=1)

#function for reducing the categories in the Public Areas column
def reducegdf(public_gdf):
    reduced_public_gdf = public_gdf
    reduced_public_gdf["Public Area"] = reduced_public_gdf["Public Area"].replace(
        ['PARKS', 'RECREATION AND WATERFRONT SITES',
            'PRESERVES AND CONSERVATION AREAS', 'CEMETERIES', 'GARDENS'],
            "Parks and Other Outdoor Areas"
    )

    return reduced_public_gdf

# %%
#Staten Island
#radius set to 1609 meters or about 1 mile
crimesper(r_crimes_gdf, r_public_gdf, 1609)
reduced_r_public_gdf = reducegdf(r_public_gdf)
reduced_r_public_gdf.head(15)
# Out:
#     OBJECTID                    Public Area   Latitude  Longitude  \
# 0        367  Parks and Other Outdoor Areas  40.614533 -74.074185
# 1        368  Parks and Other Outdoor Areas  40.510392 -74.230405
# 2        369               PUBLIC LIBRARIES  40.595802 -74.063027
# 3        370               PUBLIC LIBRARIES  40.590395 -74.101138
# 4        371  Parks and Other Outdoor Areas  40.638748 -74.083899
# 5        372  Parks and Other Outdoor Areas  40.636564 -74.160471
# 6        373  Parks and Other Outdoor Areas  40.576267 -74.203381
# 7        374  Parks and Other Outdoor Areas  40.608690 -74.119578
# 8        375  Parks and Other Outdoor Areas  40.639297 -74.120934
# 9        376  Parks and Other Outdoor Areas  40.526901 -74.163615
# 10       377  Parks and Other Outdoor Areas  40.538396 -74.187137
# 11       378  Parks and Other Outdoor Areas  40.606412 -74.141860
# 12       379  Parks and Other Outdoor Areas  40.643569 -74.079843
# 13       380  Parks and Other Outdoor Areas  40.641091 -74.081718
# 14       381               PUBLIC LIBRARIES  40.534058 -74.193235
#
#                              geometry  ROBBERY  \
# 0   POINT (4521189.101 -12545573.503)       10
# 1   POINT (4509596.170 -12609255.973)        0
# 2   POINT (4519103.997 -12541048.240)        5
# 3   POINT (4518502.095 -12556517.429)        2
# 4   POINT (4523884.728 -12549515.585)       24
# 5   POINT (4523641.579 -12580672.111)        4
# 6   POINT (4516929.352 -12598196.087)        0
# 7   POINT (4520538.708 -12564014.907)       10
# 8   POINT (4523945.891 -12564566.701)        6
# 9   POINT (4511433.992 -12581954.507)        0
# 10  POINT (4512713.635 -12591556.612)        0
# 11  POINT (4520285.052 -12573086.022)        1
# 12  POINT (4524421.368 -12547869.371)       41
# 13  POINT (4524145.522 -12548630.457)       24
# 14  POINT (4512230.647 -12594048.322)        2
#
#     MURDER & NON-NEGL. MANSLAUGHTER  RAPE  Total Crimes
# 0                                 1     0            11
# 1                                 0     0             0
# 2                                 0     0             5
# 3                                 0     0             2
# 4                                 0     0            24
# 5                                 1     0             5
# 6                                 0     0             0
# 7                                 0     0            10
# 8                                 1     0             7
# 9                                 0     0             0
# 10                                0     0             0
# 11                                0     0             1
# 12                                0    15            56
# 13                                0     0            24
# 14                                0     0             2

# %% [markdown]
# **Warning: This next part of code may take a while to run**
# - may take upwards of 10 mins

# %%
#Queens
crimesper(q_crimes_gdf, q_public_gdf, 1609)
reduced_q_public_gdf = reducegdf(q_public_gdf)
reduced_q_public_gdf.head(15)
# Out:
#     OBJECTID                        facname                      Public Area  \
# 0       3732                JACKSON HEIGHTS                 PUBLIC LIBRARIES
# 1       3733                     AUBURNDALE                 PUBLIC LIBRARIES
# 2       3734                           PARK  STREETSCAPES, PLAZAS, AND MALLS
# 3       3735                        POMONOK                 PUBLIC LIBRARIES
# 4       3736                         CORONA                 PUBLIC LIBRARIES
# 5       3737                  MIDLAND MALLS  STREETSCAPES, PLAZAS, AND MALLS
# 6       3738                  SOUTH JAMAICA                 PUBLIC LIBRARIES
# 7       3739  NORELLI-HARGREAVES PLAYGROUND    Parks and Other Outdoor Areas
# 8       3740               STRIPPOLI SQUARE  STREETSCAPES, PLAZAS, AND MALLS
# 9       3741                         GARDEN    Parks and Other Outdoor Areas
# 10      3742                   PETERS FIELD    Parks and Other Outdoor Areas
# 11      3743         HERMON A. MACNEIL PARK    Parks and Other Outdoor Areas
# 12      3744                           PARK  STREETSCAPES, PLAZAS, AND MALLS
# 13      3745                           PARK                      UNDEVELOPED
# 14      3746            FRANK PRINCIPE PARK    Parks and Other Outdoor Areas
#
#    Public Area (supergroup)   Latitude  Longitude  \
# 0                 LIBRARIES  40.750202 -73.885069
# 1                 LIBRARIES  40.773751 -73.796349
# 2          PARKS AND PLAZAS  40.728758 -73.879273
# 3                 LIBRARIES  40.733033 -73.809879
# 4                 LIBRARIES  40.750890 -73.861980
# 5          PARKS AND PLAZAS  40.717146 -73.784115
# 6                 LIBRARIES  40.695630 -73.790177
# 7          PARKS AND PLAZAS  40.690179 -73.808738
# 8          PARKS AND PLAZAS  40.757186 -73.907573
# 9          PARKS AND PLAZAS  40.597016 -73.768579
# 10         PARKS AND PLAZAS  40.706015 -73.774839
# 11         PARKS AND PLAZAS  40.793060 -73.851707
# 12         PARKS AND PLAZAS  40.707658 -73.859012
# 13         PARKS AND PLAZAS  40.600821 -73.822238
# 14         PARKS AND PLAZAS  40.727467 -73.904739
#
#                              geometry  RAPE  ROBBERY  \
# 0   POINT (4536291.697 -12469290.329)     0      147
# 1   POINT (4538913.171 -12433803.631)     0        2
# 2   POINT (4533904.605 -12466966.372)     0       20
# 3   POINT (4534380.490 -12439203.250)     9       17
# 4   POINT (4536368.366 -12460037.036)     0      164
# 5   POINT (4532611.951 -12428925.002)     0       31
# 6   POINT (4530216.827 -12431342.201)     0       54
# 7   POINT (4529610.044 -12438747.580)     0       74
# 8   POINT (4537069.228 -12478321.900)     0       39
# 9   POINT (4519239.190 -12422735.023)     0       11
# 10  POINT (4531372.841 -12425228.635)     0       25
# 11  POINT (4541062.620 -12455923.762)     0        8
# 12  POINT (4531555.733 -12458848.470)     0       11
# 13  POINT (4519662.761 -12444139.272)     0        2
# 14  POINT (4533760.934 -12477184.047)     0       11
#
#     MURDER & NON-NEGL. MANSLAUGHTER  Total Crimes
# 0                                 2           149
# 1                                 0             2
# 2                                 0            20
# 3                                 0            26
# 4                                 3           167
# 5                                 0            31
# 6                                 1            55
# 7                                 0            74
# 8                                 2            41
# 9                                 0            11
# 10                                0            25
# 11                                0             8
# 12                                0            11
# 13                                0             2
# 14                                1            12

# %%
crimesper(k_crimes_gdf, k_public_gdf, 1609)
# Out:
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 crimesper(k_crimes_gdf, k_public_gdf, 1609)
#       2 reduced_k_public_gdf = reducegdf(k_public_gdf)
#       3 reduced_k_public_gdf.head(15)
#
# Cell In[18], line 15, in crimesper(crimes_gdf, public_gdf, radius)
#      10 crimes_gdf_each = crimes_gdf[crimes_gdf["Offense"] == offense]
#      12 for i in range(len(public_gdf)):
#      13
#      14     # Calculate the distances between all pairs of points
# ---> 15     distances = gpd.GeoSeries(crimes_gdf_each.geometry).distance(public_gdf.geometry.iloc[i])
#      17     # Filter the pairs where the distance is within the radius
#      18     within_radius = distances <= radius
#
# File c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\geopandas\base.py:2577, in GeoPandasBase.distance(self, other, align)
#    2483 def distance(self, other, align=True):
#    2484     """Returns a ``Series`` containing the distance to aligned `other`.
#    2485
#    2486     The operation works on a 1-to-1 row-wise manner:
#    (...)
#    2575     dtype: float64
#    2576     """
# -> 2577     return _binary_op("distance", self, other, align)
#
# File c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\geopandas\base.py:63, in _binary_op(op, this, other, align, *args, **kwargs)
#      60 def _binary_op(op, this, other, align, *args, **kwargs):
#      61     # type: (str, GeoSeries, GeoSeries, args/kwargs) -> Series[bool/float]
#      62     """Binary operation on GeoSeries objects that returns a Series"""
# ---> 63     data, index = _delegate_binary_method(op, this, other, align, *args, **kwargs)
#      64     return Series(data, index=index)
#
# File c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\geopandas\base.py:47, in _delegate_binary_method(op, this, other, align, *args, **kwargs)
#      44 else:
#      45     raise TypeError(type(this), type(other))
# ---> 47 data = getattr(a_this, op)(other, *args, **kwargs)
#      48 return data, this.index
#
# File c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\geopandas\array.py:693, in GeometryArray.distance(self, other)
#     691 def distance(self, other):
#     692     self.check_geographic_crs(stacklevel=6)
# --> 693     return self._binary_method("distance", self, other)
#
# File c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\geopandas\array.py:611, in GeometryArray._binary_method(op, left, right, **kwargs)
#     608         _crs_mismatch_warn(left, right, stacklevel=7)
#     609     right = right._data
# --> 611 return getattr(vectorized, op)(left._data, right, **kwargs)
#
# File c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\geopandas\_vectorized.py:982, in distance(data, other)
#     980 def distance(data, other):
#     981     if compat.USE_SHAPELY_20:
# --> 982         return shapely.distance(data, other)
#     983     elif compat.USE_PYGEOS:
#     984         return _binary_method("distance", data, other)
#
# File c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\decorators.py:77, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      75     for arr in array_args:
#      76         arr.flags.writeable = False
# ---> 77     return func(*args, **kwargs)
#      78 finally:
#      79     for arr, old_flag in zip(array_args, old_flags):
#
# File c:\Users\54qb3\anaconda3\envs\dev\lib\site-packages\shapely\measurement.py:74, in distance(a, b, **kwargs)
#      48 @multithreading_enabled
#      49 def distance(a, b, **kwargs):
#      50     """Computes the Cartesian distance between two geometries.
#      51
#      52     Parameters
#    (...)
#      72     nan
#      73     """
# ---> 74     return lib.distance(a, b, **kwargs)
#
# KeyboardInterrupt:

# %%
k_public_gdf["Total Crimes"] = k_public_gdf[['ROBBERY', 'MURDER & NON-NEGL. MANSLAUGHTER', 'RAPE']].sum(axis=1)
k_public_gdf.columns
# Out:
# Index(['facname', 'Public Area', 'Public Area (supergroup)', 'boro',
#        'Latitude', 'Longitude', 'geometry', 'RAPE', 'ROBBERY',
#        'MURDER & NON-NEGL. MANSLAUGHTER', 'Total Crimes'],
#       dtype='object')

# %%
reduced_k_public_gdf = reducegdf(k_public_gdf)
reduced_k_public_gdf.head(15)
# Out:
#                                       facname  \
# OBJECTID
# 3                          IRVING SQUARE PARK
# 5                           GRAVESEND LIBRARY
# 22                             DEKALB LIBRARY
# 36                            MIDWOOD LIBRARY
# 41        UNITED COMMUNITY CENTERS YOUTH FARM
# 66                             FARMERS GARDEN
# 73                          CADMAN PLAZA PARK
# 137                       NEW UTRECHT LIBRARY
# 149                                      PARK
# 202                          HIGHLAWN LIBRARY
# 203           CRYSTAL WELLS BLOCK ASSOCIATION
# 204                          BENSONHURST PARK
# 248                             MARCY LIBRARY
# 264                         CORTELYOU LIBRARY
# 270                       JAMAICA BAY LIBRARY
#
#                               Public Area Public Area (supergroup)      boro  \
# OBJECTID
# 3           Parks and Other Outdoor Areas         PARKS AND PLAZAS  BROOKLYN
# 5                        PUBLIC LIBRARIES                LIBRARIES  BROOKLYN
# 22                       PUBLIC LIBRARIES                LIBRARIES  BROOKLYN
# 36                       PUBLIC LIBRARIES                LIBRARIES  BROOKLYN
# 41          Parks and Other Outdoor Areas         PARKS AND PLAZAS  BROOKLYN
# 66          Parks and Other Outdoor Areas         PARKS AND PLAZAS  BROOKLYN
# 73          Parks and Other Outdoor Areas         PARKS AND PLAZAS  BROOKLYN
# 137                      PUBLIC LIBRARIES                LIBRARIES  BROOKLYN
# 149       STREETSCAPES, PLAZAS, AND MALLS         PARKS AND PLAZAS  BROOKLYN
# 202                      PUBLIC LIBRARIES                LIBRARIES  BROOKLYN
# 203         Parks and Other Outdoor Areas         PARKS AND PLAZAS  BROOKLYN
# 204         Parks and Other Outdoor Areas         PARKS AND PLAZAS  BROOKLYN
# 248                      PUBLIC LIBRARIES                LIBRARIES  BROOKLYN
# 264                      PUBLIC LIBRARIES                LIBRARIES  BROOKLYN
# 270                      PUBLIC LIBRARIES                LIBRARIES  BROOKLYN
#
#            Latitude  Longitude                           geometry  RAPE  \
# OBJECTID
# 3         40.692443 -73.909184  POINT (4529862.012 -12478969.228)     0
# 5         40.590603 -73.971754  POINT (4518525.201 -12504147.477)     0
# 22        40.694786 -73.928404  POINT (4530122.822 -12486693.273)     0
# 36        40.624849 -73.964388  POINT (4522337.549 -12501178.519)     0
# 41        40.659697 -73.907876  POINT (4526216.722 -12478443.640)     0
# 66        40.674607 -73.918219  POINT (4527876.572 -12482598.932)     0
# 73        40.698443 -73.990626  POINT (4530530.000 -12511760.557)     0
# 137       40.608019 -74.003341  POINT (4520463.964 -12516894.693)     9
# 149       40.682249 -74.002630  POINT (4528727.269 -12516607.511)     4
# 202       40.605689 -73.986230  POINT (4520204.633 -12509986.497)     0
# 203       40.678075 -73.875397  POINT (4528262.554 -12465412.616)     0
# 204       40.596513 -74.001302  POINT (4519183.140 -12516071.163)     9
# 248       40.691631 -73.951264  POINT (4529771.631 -12495891.922)     0
# 264       40.640586 -73.965975  POINT (4524089.297 -12501818.206)     0
# 270       40.634525 -73.889248  POINT (4523414.637 -12470966.584)     0
#
#           ROBBERY  MURDER & NON-NEGL. MANSLAUGHTER  Total Crimes
# OBJECTID
# 3              92                                1            93
# 5              20                                0            20
# 22             94                                4            98
# 36             22                                0            22
# 41            105                                2           107
# 66             69                                2            71
# 73             48                                0            48
# 137            29                                0            38
# 149            22                                1            27
# 202            18                                1            19
# 203            86                                1            87
# 204            24                                0            33
# 248            82                                4            86
# 264            33                                1            34
# 270            14                                0            14

# %%
#Bronx
crimesper(x_crimes_gdf, x_public_gdf, 1609)
reduced_x_public_gdf = reducegdf(x_public_gdf)
reduced_x_public_gdf.head(15)
# Out:
#     OBJECTID               facname                      Public Area  \
# 0       5348       ST. LUKE'S PARK    Parks and Other Outdoor Areas
# 1       5349     SOUNDVIEW LIBRARY                 PUBLIC LIBRARIES
# 2       5350  HORSESHOE PLAYGROUND    Parks and Other Outdoor Areas
# 3       5351    BAYCHESTER LIBRARY                 PUBLIC LIBRARIES
# 4       5352    ESTELLA DIGGS PARK    Parks and Other Outdoor Areas
# 5       5353       MOSHOLU LIBRARY                 PUBLIC LIBRARIES
# 6       5354         AQUEDUCT WALK    Parks and Other Outdoor Areas
# 7       5355          CROTONA PARK    Parks and Other Outdoor Areas
# 8       5356     WAKEFIELD LIBRARY                 PUBLIC LIBRARIES
# 9       5357      BRYAN PARK PLAZA  STREETSCAPES, PLAZAS, AND MALLS
# 10      5358                GARDEN    Parks and Other Outdoor Areas
# 11      5359      CASTLE HILL PARK    Parks and Other Outdoor Areas
# 12      5360        GARDEN OF EDEN    Parks and Other Outdoor Areas
# 13      5361     WOODSTOCK LIBRARY                 PUBLIC LIBRARIES
# 14      5362       GRANJA FARM OTF    Parks and Other Outdoor Areas
#
#    Public Area (supergroup)   Latitude  Longitude  \
# 0          PARKS AND PLAZAS  40.805637 -73.915384
# 1                 LIBRARIES  40.818708 -73.862889
# 2          PARKS AND PLAZAS  40.824121 -73.897692
# 3                 LIBRARIES  40.870278 -73.828611
# 4          PARKS AND PLAZAS  40.828938 -73.906177
# 5                 LIBRARIES  40.874383 -73.878394
# 6          PARKS AND PLAZAS  40.865127 -73.902162
# 7          PARKS AND PLAZAS  40.840033 -73.895347
# 8                 LIBRARIES  40.891098 -73.859523
# 9          PARKS AND PLAZAS  40.862172 -73.894218
# 10         PARKS AND PLAZAS  40.828490 -73.906253
# 11         PARKS AND PLAZAS  40.811903 -73.847503
# 12         PARKS AND PLAZAS  40.843464 -73.907394
# 13                LIBRARIES  40.820640 -73.904628
# 14         PARKS AND PLAZAS  40.815697 -73.911520
#
#                              geometry  RAPE  ROBBERY  \
# 0   POINT (4542462.771 -12481459.815)     0      212
# 1   POINT (4543917.734 -12460401.056)     0       70
# 2   POINT (4544520.386 -12474354.807)    14      196
# 3   POINT (4549658.510 -12446685.940)     0       26
# 4   POINT (4545056.609 -12477761.571)     0      210
# 5   POINT (4550115.474 -12466613.843)    32       70
# 6   POINT (4549085.134 -12476149.225)    16      222
# 7   POINT (4546291.689 -12473413.733)     0      125
# 8   POINT (4551976.165 -12459052.920)     0       85
# 9   POINT (4548756.198 -12472960.694)     0      257
# 10  POINT (4545006.714 -12477792.090)     0      214
# 11  POINT (4543160.264 -12454241.353)     0       16
# 12  POINT (4546673.568 -12478250.010)     0      210
# 13  POINT (4544132.880 -12477139.461)     0      228
# 14  POINT (4543582.622 -12479907.318)    24      190
#
#     MURDER & NON-NEGL. MANSLAUGHTER  Total Crimes
# 0                                 5           217
# 1                                 0            70
# 2                                 3           213
# 3                                 0            26
# 4                                 8           218
# 5                                 4           106
# 6                                 3           241
# 7                                 4           129
# 8                                 3            88
# 9                                 4           261
# 10                                8           222
# 11                                1            17
# 12                                6           216
# 13                                7           235
# 14                                3           217

# %%
#Manhattan
crimesper(m_crimes_gdf, m_public_gdf, 1609)
reduced_m_public_gdf = reducegdf(m_public_gdf)
reduced_m_public_gdf.head(15)
# Out:
#     OBJECTID                                     facname  \
# 0       4106                        BRADHURST AVE GARDEN
# 1       4107                               DAMROSCH PARK
# 2       4108                                CHELSEA PARK
# 3       4109                          METROPOLITAN TOWER
# 4       4110                                   BEL CANTO
# 5       4111         733 PARK AVENUE, NEW YORK, NY 10021
# 6       4112                         BLEECKER PLAYGROUND
# 7       4113                         MARGRICHANTE GARDEN
# 8       4114                              EAST PROMENADE
# 9       4115                                COLONELS ROW
# 10      4116                                   PECK SLIP
# 11      4117                    JEFFERSON MARKET LIBRARY
# 12      4118                       GRAND CENTRAL LIBRARY
# 13      4119                     MACOMB'S BRIDGE LIBRARY
# 14      4120  STAVROS NIARCHOS FOUNDATION LIBRARY (SNFL)
#
#                         Public Area Public Area (supergroup)   Latitude  \
# 0     Parks and Other Outdoor Areas         PARKS AND PLAZAS  40.827666
# 1     Parks and Other Outdoor Areas         PARKS AND PLAZAS  40.772213
# 2     Parks and Other Outdoor Areas         PARKS AND PLAZAS  40.749942
# 3      PRIVATELY OWNED PUBLIC SPACE         PARKS AND PLAZAS  40.764801
# 4      PRIVATELY OWNED PUBLIC SPACE         PARKS AND PLAZAS  40.775278
# 5      PRIVATELY OWNED PUBLIC SPACE         PARKS AND PLAZAS  40.770083
# 6     Parks and Other Outdoor Areas         PARKS AND PLAZAS  40.736352
# 7     Parks and Other Outdoor Areas         PARKS AND PLAZAS  40.813752
# 8     Parks and Other Outdoor Areas         PARKS AND PLAZAS  40.765531
# 9     Parks and Other Outdoor Areas         PARKS AND PLAZAS  40.690715
# 10  STREETSCAPES, PLAZAS, AND MALLS         PARKS AND PLAZAS  40.707571
# 11                 PUBLIC LIBRARIES                LIBRARIES  40.734605
# 12                 PUBLIC LIBRARIES                LIBRARIES  40.754072
# 13                 PUBLIC LIBRARIES                LIBRARIES  40.825367
# 14                 PUBLIC LIBRARIES                LIBRARIES  40.751778
#
#     Longitude                           geometry  ROBBERY  RAPE  \
# 0  -73.939326  POINT (4544914.964 -12491086.537)      175     0
# 1  -73.984994  POINT (4538741.974 -12509487.607)      117     8
# 2  -74.000728  POINT (4536262.754 -12515839.336)       99     8
# 3  -73.979238  POINT (4537916.851 -12507165.666)       77     0
# 4  -73.982638  POINT (4539083.176 -12508536.879)       72     8
# 5  -73.964118  POINT (4538504.927 -12501069.584)       89    12
# 6  -74.005565  POINT (4534749.991 -12517793.195)       95     8
# 7  -73.943443  POINT (4543366.078 -12492743.219)      221    22
# 8  -73.945446  POINT (4537998.153 -12493549.413)        3     0
# 9  -74.018823  POINT (4529669.674 -12523151.468)        0     0
# 10 -74.001388  POINT (4531546.094 -12516105.975)       36     0
# 11 -73.999167  POINT (4534555.450 -12515208.763)      194     8
# 12 -73.973498  POINT (4536722.543 -12504850.871)       76     5
# 13 -73.935512  POINT (4544659.029 -12489552.112)       84     0
# 14 -73.981527  POINT (4536467.170 -12508088.717)      160     0
#
#     MURDER & NON-NEGL. MANSLAUGHTER  Total Crimes
# 0                                 8           183
# 1                                 2           127
# 2                                 1           108
# 3                                 0            77
# 4                                 0            80
# 5                                 0           101
# 6                                 0           103
# 7                                 8           251
# 8                                 0             3
# 9                                 0             0
# 10                                2            38
# 11                                1           203
# 12                                0            81
# 13                                6            90
# 14                                2           162

# %%
#formula for getting the summary stats of each borough
def gdf_summary_stats(reduced_gdf):
    summary_stats = reduced_gdf.groupby("Public Area")[['ROBBERY', 'MURDER & NON-NEGL. MANSLAUGHTER', 'RAPE', 'Total Crimes']].describe()
    return summary_stats

# %%
gdf_summary_stats(reduced_r_public_gdf)["ROBBERY"]
# Out:
#                                  count      mean        std  min   25%  50%  \
# Public Area
# PUBLIC LIBRARIES                   4.0  2.500000   1.732051  1.0  1.75  2.0
# Parks and Other Outdoor Areas     19.0  7.947368  10.746957  0.0  0.50  5.0
# STREETSCAPES, PLAZAS, AND MALLS    1.0  5.000000        NaN  5.0  5.00  5.0
#
#                                   75%   max
# Public Area
# PUBLIC LIBRARIES                 2.75   5.0
# Parks and Other Outdoor Areas    9.50  41.0
# STREETSCAPES, PLAZAS, AND MALLS  5.00   5.0

# %%
gdf_summary_stats(reduced_q_public_gdf)["Total Crimes"]
# Out:
#                                  count       mean        std  min    25%  \
# Public Area
# PUBLIC LIBRARIES                  20.0  46.700000  54.463991  2.0  12.75
# Parks and Other Outdoor Areas     35.0  38.657143  44.686452  0.0   7.50
# STREETSCAPES, PLAZAS, AND MALLS   25.0  32.120000  41.553500  0.0   8.00
# UNDEVELOPED                        4.0  11.750000   6.849574  2.0  10.25
#
#                                   50%    75%    max
# Public Area
# PUBLIC LIBRARIES                 17.0  56.25  167.0
# Parks and Other Outdoor Areas    17.0  59.00  163.0
# STREETSCAPES, PLAZAS, AND MALLS  16.0  41.00  166.0
# UNDEVELOPED                      13.5  15.00   18.0

# %%
gdf_summary_stats(reduced_k_public_gdf)
# Out:
#                                 ROBBERY                                     \
#                                   count       mean        std   min    25%
# Public Area
# PUBLIC LIBRARIES                   22.0  40.954545  32.768273   4.0  17.25
# Parks and Other Outdoor Areas      54.0  73.037037  33.586814   6.0  52.25
# STREETSCAPES, PLAZAS, AND MALLS    20.0  43.850000  41.265858  11.0  13.00
#
#                                                      \
#                                   50%    75%    max
# Public Area
# PUBLIC LIBRARIES                 28.5  54.75  125.0
# Parks and Other Outdoor Areas    79.0  96.50  130.0
# STREETSCAPES, PLAZAS, AND MALLS  23.0  62.25  149.0
#
#                                 MURDER & NON-NEGL. MANSLAUGHTER            \
#                                                           count      mean
# Public Area
# PUBLIC LIBRARIES                                           22.0  1.000000
# Parks and Other Outdoor Areas                              54.0  2.277778
# STREETSCAPES, PLAZAS, AND MALLS                            20.0  0.900000
#
#                                  ... RAPE       Total Crimes             \
#                                  ...  75%   max        count       mean
# Public Area                      ...
# PUBLIC LIBRARIES                 ...  0.0  16.0         22.0  43.681818
# Parks and Other Outdoor Areas    ...  6.5  28.0         54.0  78.814815
# STREETSCAPES, PLAZAS, AND MALLS  ...  4.0  16.0         20.0  47.100000
#
#
#                                        std   min    25%   50%     75%    max
# Public Area
# PUBLIC LIBRARIES                 35.132926   4.0  18.25  30.0   61.75  127.0
# Parks and Other Outdoor Areas    34.864197   6.0  54.50  88.5  103.50  136.0
# STREETSCAPES, PLAZAS, AND MALLS  44.492341  12.0  13.00  26.0   65.00  166.0
#
# [3 rows x 32 columns]

# %%
gdf_summary_stats(reduced_x_public_gdf)
# Out:
#                                 ROBBERY                                 \
#                                   count        mean         std    min
# Public Area
# PUBLIC LIBRARIES                   11.0  117.818182  101.117573    2.0
# Parks and Other Outdoor Areas      30.0  164.500000   76.569891    1.0
# STREETSCAPES, PLAZAS, AND MALLS    12.0  134.083333   95.234121   11.0
# UNDEVELOPED                         1.0  208.000000         NaN  208.0
#
#                                                               \
#                                     25%    50%    75%    max
# Public Area
# PUBLIC LIBRARIES                  48.00   85.0  167.5  333.0
# Parks and Other Outdoor Areas    121.25  193.0  212.0  302.0
# STREETSCAPES, PLAZAS, AND MALLS   32.50  145.0  215.5  257.0
# UNDEVELOPED                      208.00  208.0  208.0  208.0
#
#                                 MURDER & NON-NEGL. MANSLAUGHTER            \
#                                                           count      mean
# Public Area
# PUBLIC LIBRARIES                                           11.0  2.545455
# Parks and Other Outdoor Areas                              30.0  4.066667
# STREETSCAPES, PLAZAS, AND MALLS                            12.0  3.416667
# UNDEVELOPED                                                 1.0  9.000000
#
#                                  ...  RAPE       Total Crimes              \
#                                  ...   75%   max        count        mean
# Public Area                      ...
# PUBLIC LIBRARIES                 ...  34.0  44.0         11.0  135.090909
# Parks and Other Outdoor Areas    ...  10.5  36.0         30.0  175.366667
# STREETSCAPES, PLAZAS, AND MALLS  ...  19.5  36.0         12.0  147.000000
# UNDEVELOPED                      ...   0.0   0.0          1.0  217.000000
#
#                                                                            \
#                                         std    min     25%    50%     75%
# Public Area
# PUBLIC LIBRARIES                 113.269991    2.0   48.00  106.0  199.50
# Parks and Other Outdoor Areas     82.582240    1.0  126.00  205.5  221.00
# STREETSCAPES, PLAZAS, AND MALLS   99.955445   11.0   33.25  181.0  223.75
# UNDEVELOPED                             NaN  217.0  217.00  217.0  217.00
#
#
#                                    max
# Public Area
# PUBLIC LIBRARIES                 374.0
# Parks and Other Outdoor Areas    331.0
# STREETSCAPES, PLAZAS, AND MALLS  265.0
# UNDEVELOPED                      217.0
#
# [4 rows x 32 columns]

# %%
gdf_summary_stats(reduced_m_public_gdf)
# Out:
#                                 ROBBERY                                 \
#                                   count        mean         std    min
# Public Area
# ACADEMIC AND SPECIAL LIBRARIES      2.0  238.000000  132.936075  144.0
# PRIVATELY OWNED PUBLIC SPACE        3.0   79.333333    8.736895   72.0
# PUBLIC LIBRARIES                   14.0  130.714286   61.047810    8.0
# Parks and Other Outdoor Areas      24.0   95.666667   86.267363    0.0
# STREETSCAPES, PLAZAS, AND MALLS    14.0  103.928571   87.661468   19.0
#
#                                                                \
#                                     25%    50%     75%    max
# Public Area
# ACADEMIC AND SPECIAL LIBRARIES   191.00  238.0  285.00  332.0
# PRIVATELY OWNED PUBLIC SPACE      74.50   77.0   83.00   89.0
# PUBLIC LIBRARIES                  86.25  127.5  170.50  236.0
# Parks and Other Outdoor Areas     23.75   79.5  162.75  298.0
# STREETSCAPES, PLAZAS, AND MALLS   59.00   74.0  126.75  357.0
#
#                                 MURDER & NON-NEGL. MANSLAUGHTER            \
#                                                           count      mean
# Public Area
# ACADEMIC AND SPECIAL LIBRARIES                              2.0  1.000000
# PRIVATELY OWNED PUBLIC SPACE                                3.0  0.000000
# PUBLIC LIBRARIES                                           14.0  2.428571
# Parks and Other Outdoor Areas                              24.0  1.916667
# STREETSCAPES, PLAZAS, AND MALLS                            14.0  1.571429
#
#                                  ...   RAPE       Total Crimes              \
#                                  ...    75%   max        count        mean
# Public Area                      ...
# ACADEMIC AND SPECIAL LIBRARIES   ...   9.75  13.0          2.0  245.500000
# PRIVATELY OWNED PUBLIC SPACE     ...  10.00  12.0          3.0   86.000000
# PUBLIC LIBRARIES                 ...   8.00  10.0         14.0  137.571429
# Parks and Other Outdoor Areas    ...   8.00  22.0         24.0  102.250000
# STREETSCAPES, PLAZAS, AND MALLS  ...   8.00  25.0         14.0  111.142857
#
#                                                                            \
#                                         std    min     25%    50%     75%
# Public Area
# ACADEMIC AND SPECIAL LIBRARIES   142.128463  145.0  195.25  245.5  295.75
# PRIVATELY OWNED PUBLIC SPACE      13.076697   77.0   78.50   80.0   90.50
# PUBLIC LIBRARIES                  65.041660    8.0   93.25  131.0  180.00
# Parks and Other Outdoor Areas     93.303735    0.0   23.75   80.5  169.75
# STREETSCAPES, PLAZAS, AND MALLS   91.089860   19.0   60.00   79.5  145.75
#
#
#                                    max
# Public Area
# ACADEMIC AND SPECIAL LIBRARIES   346.0
# PRIVATELY OWNED PUBLIC SPACE     101.0
# PUBLIC LIBRARIES                 250.0
# Parks and Other Outdoor Areas    317.0
# STREETSCAPES, PLAZAS, AND MALLS  358.0
#
# [5 rows x 32 columns]

# %%
#exporting to csv so the next file of code is possible
path = "C:/Users/54qb3/Documents/Project-1/output_data/"
pd.DataFrame(reduced_r_public_gdf).to_csv(f"{path}reduced_r_public_gdf.csv")
pd.DataFrame(reduced_q_public_gdf).to_csv(f"{path}reduced_q_public_gdf.csv")
pd.DataFrame(reduced_k_public_gdf).to_csv(f"{path}reduced_k_public_gdf.csv")
pd.DataFrame(reduced_x_public_gdf).to_csv(f"{path}reduced_x_public_gdf.csv")
pd.DataFrame(reduced_m_public_gdf).to_csv(f"{path}reduced_m_public_gdf.csv")

# %%
#exporting to csv so the next file of code is possible
path = "C:/Users/54qb3/Documents/Project-1/output_data/"
pd.DataFrame(r_crimes_gdf).to_csv(f"{path}r_crimes_gdf.csv")
pd.DataFrame(q_crimes_gdf).to_csv(f"{path}q_crimes_gdf.csv")
pd.DataFrame(k_crimes_gdf).to_csv(f"{path}k_crimes_gdf.csv")
pd.DataFrame(x_crimes_gdf).to_csv(f"{path}x_crimes_gdf.csv")
pd.DataFrame(m_crimes_gdf).to_csv(f"{path}m_crimes_gdf.csv")

# %%
import hvplot.pandas

k_crimes_map = k_crimes_gdf.hvplot.points(
    "Longitude",
    "Latitude",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    alpha = 0.5,
    #hover_cols = ['ROBBERY', 'MURDER & NON-NEGL. MANSLAUGHTER', 'RAPE', 'Total Crimes']
)
k_crimes_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Longitude,Latitude]
